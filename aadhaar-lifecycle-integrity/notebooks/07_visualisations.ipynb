# %% [markdown]
# # Visualizations

# %%
import syssys.path.insert(0, '..')import pandas as pdfrom src import visuals, config# Load final datarisk_df = pd.read_csv(config.PROCESSED_DATA_DIR / 'risk_analysis.csv')# Generate visualizationsvisuals.plot_isi_distribution(risk_df)visuals.plot_duv_distribution(risk_df)visuals.plot_isi_duv_scatter(risk_df)visuals.plot_risk_heatmap(risk_df)# Save summary tablevisuals.save_table(risk_df.describe(), 'summary_statistics')print('Visualizations saved to', config.FIGURES_DIR)
