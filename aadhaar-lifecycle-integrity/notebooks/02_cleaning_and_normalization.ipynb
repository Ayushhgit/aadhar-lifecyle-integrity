# %% [markdown]
# # Cleaning and Normalization

# %%
import syssys.path.insert(0, '..')from src import loaders, preprocess, config# Load dataenrolment = loaders.load_enrolment_data()biometric = loaders.load_biometric_updates()demographic = loaders.load_demographic_updates()# Clean dataenrolment_clean = preprocess.clean_enrolment_data(enrolment)biometric_clean = preprocess.clean_biometric_updates(biometric)demographic_clean = preprocess.clean_demographic_updates(demographic)# Save to interimenrolment_clean.to_csv(config.INTERIM_DATA_DIR / 'enrolment_clean.csv', index=False)biometric_clean.to_csv(config.INTERIM_DATA_DIR / 'biometric_clean.csv', index=False)demographic_clean.to_csv(config.INTERIM_DATA_DIR / 'demographic_clean.csv', index=False)
