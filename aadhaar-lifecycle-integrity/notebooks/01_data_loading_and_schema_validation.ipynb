# %% [markdown]
# # Data Loading and Schema Validation

# %%
import syssys.path.insert(0, '..')from src import loaders, config# Load datasetsenrolment = loaders.load_enrolment_data()biometric = loaders.load_biometric_updates()demographic = loaders.load_demographic_updates()# Validate schemasloaders.validate_schema(enrolment, config.ENROLMENT_SCHEMA, 'Enrolment')loaders.validate_schema(biometric, config.BIOMETRIC_UPDATE_SCHEMA, 'Biometric')loaders.validate_schema(demographic, config.DEMOGRAPHIC_UPDATE_SCHEMA, 'Demographic')print('Data shapes:', enrolment.shape, biometric.shape, demographic.shape)
